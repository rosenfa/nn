# %% [markdown]
# This Notebook will introduce the basics of gradient descent.  We will use the function, x*x*np.log(x)-x and derivative 2*x*np.log(x)+x-1 we discussed in class.

# %%
import matplotlib.pyplot as plt
import numpy as np
#cost = y - y-hat (guess)
def function(x):
    return x*x*np.log(x)-x

def function_prime(x):
    return 2*x*np.log(x)+x-1

# %% [markdown]
# Let's take the values of the function in steps of 0.1 (using numpy's arange method) for both the function and the derivative.

# %%
x1 = np.arange(0.1,5,0.1)
y1= function(x1)
    
x2 = np.arange(0.1,5,0.1)
y2= function_prime(x1)

# %% [markdown]
# Let's plot them now...

# %%
plt.plot(x1,y1)
plt.plot(x2,y2)
plt.grid()

plt.xlim(0,4)

plt.title('Functions in Numpy!',fontsize=10)

plt.xlabel('X',fontsize=14)
plt.ylabel('Y',fontsize=14)

plt.savefig('how_to_caclulate_natural_logarithm_in_python.png', bbox_inches='tight')
plt.show()

# %% [markdown]
# Here is a basic gradient descent implementation.  We start the search for the minimum at 2 (we know it's 1, but this shows how it can be experically found).  Every iteration we print t, the derivative of the function we are trying to solve, and update the value, next_x. We end the loop when we hit max_iter (max. iterations) or when we break out because the difference, difference, between the old and new value is less than epsilon (0.00001).  Feel free to play with the values for alpha -- the step size.

# %%
next_x = 2
alpha = 0.2
max_iter=50
epsilon = 0.00001
print("The new initial value of the search is " + str(next_x))
for i in range(max_iter):
    current = next_x
    t=function_prime(current)
    next_x = next_x - alpha*t
    print("Iteration number: " + str(i+1))
    print("The derivative is " + str(t))
    print("The change in value is " + str(alpha*t))
    print("The new value in the search is " + str(next_x))
    difference = next_x - current
    #print(difference)
    if (abs(difference)<epsilon):
        break
print("answer is " + str(next_x))
# Out:
# The new initial value of the search is 2
# Iteration number: 1
# The derivative is 3.7725887222397816
# The change in value is 0.7545177444479564
# The new value in the search is 1.2454822555520435
# Iteration number: 2
# The derivative is 0.7923057815799788
# The change in value is 0.15846115631599578
# The new value in the search is 1.0870210992360478
# Iteration number: 3
# The derivative is 0.26842539447643476
# The change in value is 0.05368507889528695
# The new value in the search is 1.0333360203407609
# Iteration number: 4
# The derivative is 0.10110720440977916
# The change in value is 0.020221440881955835
# The new value in the search is 1.013114579458805
# Iteration number: 5
# The derivative is 0.039514983594123754
# The change in value is 0.00790299671882475
# The new value in the search is 1.0052115827399803
# Iteration number: 6
# The derivative is 0.01566186175393436
# The change in value is 0.003132372350786872
# The new value in the search is 1.0020792103891936
# Iteration number: 7
# The derivative is 0.006241951290311798
# The change in value is 0.0012483902580623597
# The new value in the search is 1.0008308201311311
# Iteration number: 8
# The derivative is 0.0024931504644019054
# The change in value is 0.0004986300928803811
# The new value in the search is 1.0003321900382507
# Iteration number: 9
# The derivative is 0.000996680452756582
# The change in value is 0.0001993360905513164
# The new value in the search is 1.0001328539476995
# Iteration number: 10
# The derivative is 0.0003985794924883379
# The change in value is 7.971589849766759e-05
# The new value in the search is 1.0000531380492017
# Iteration number: 11
# The derivative is 0.0001594169712073601
# The change in value is 3.188339424147202e-05
# The new value in the search is 1.0000212546549603
# Iteration number: 12
# The derivative is 6.376441663791255e-05
# The change in value is 1.275288332758251e-05
# The new value in the search is 1.0000085017716327
# Iteration number: 13
# The derivative is 2.5505387178048622e-05
# The change in value is 5.1010774356097245e-06
# The new value in the search is 1.0000034006941971
# answer is 1.0000034006941971

# %% [markdown]
# Sometimes have a large learning rate will prevent us from converging.  Let's consider two functions: x^2 − 2x + 3 and its derivative, 2x - 2. Note that the optimal minimum will be at x = 1 (2x - 2 = 0), but let's start the search at 2 and try to find that out with gradient descent with alpha set to 20.

# %%
next_x = 2
alpha = 20 #instead of 0.2
max_iter=50
epsilon = 0.00001
print("The new initial value of the search is " + str(next_x))
for i in range(max_iter):
    current = next_x
    t=(2 * next_x) - 2 #function_prime(current)
    next_x = next_x - alpha*t
    print("Iteration number: " + str(i+1))
    print("The derivative is " + str(t))
    print("The change in value is " + str(alpha*t))
    print("The new value in the search is " + str(next_x))
    difference = next_x - current
    #print(difference)
    if (abs(difference)<epsilon):
        break
print("answer is " + str(next_x))
# Out:
# The new initial value of the search is 2
# Iteration number: 1
# The derivative is 2
# The change in value is 40
# The new value in the search is -38
# Iteration number: 2
# The derivative is -78
# The change in value is -1560
# The new value in the search is 1522
# Iteration number: 3
# The derivative is 3042
# The change in value is 60840
# The new value in the search is -59318
# Iteration number: 4
# The derivative is -118638
# The change in value is -2372760
# The new value in the search is 2313442
# Iteration number: 5
# The derivative is 4626882
# The change in value is 92537640
# The new value in the search is -90224198
# Iteration number: 6
# The derivative is -180448398
# The change in value is -3608967960
# The new value in the search is 3518743762
# Iteration number: 7
# The derivative is 7037487522
# The change in value is 140749750440
# The new value in the search is -137231006678
# Iteration number: 8
# The derivative is -274462013358
# The change in value is -5489240267160
# The new value in the search is 5352009260482
# Iteration number: 9
# The derivative is 10704018520962
# The change in value is 214080370419240
# The new value in the search is -208728361158758
# Iteration number: 10
# The derivative is -417456722317518
# The change in value is -8349134446350360
# The new value in the search is 8140406085191602
# Iteration number: 11
# The derivative is 16280812170383202
# The change in value is 325616243407664040
# The new value in the search is -317475837322472438
# Iteration number: 12
# The derivative is -634951674644944878
# The change in value is -12699033492898897560
# The new value in the search is 12381557655576425122
# Iteration number: 13
# The derivative is 24763115311152850242
# The change in value is 495262306223057004840
# The new value in the search is -482880748567480579718
# Iteration number: 14
# The derivative is -965761497134961159438
# The change in value is -19315229942699223188760
# The new value in the search is 18832349194131742609042
# Iteration number: 15
# The derivative is 37664698388263485218082
# The change in value is 753293967765269704361640
# The new value in the search is -734461618571137961752598
# Iteration number: 16
# The derivative is -1468923237142275923505198
# The change in value is -29378464742845518470103960
# The new value in the search is 28644003124274380508351362
# Iteration number: 17
# The derivative is 57288006248548761016702722
# The change in value is 1145760124970975220334054440
# The new value in the search is -1117116121846700839825703078
# Iteration number: 18
# The derivative is -2234232243693401679651406158
# The change in value is -44684644873868033593028123160
# The new value in the search is 43567528752021332753202420082
# Iteration number: 19
# The derivative is 87135057504042665506404840162
# The change in value is 1742701150080853310128096803240
# The new value in the search is -1699133621328831977374894383158
# Iteration number: 20
# The derivative is -3398267242657663954749788766318
# The change in value is -67965344853153279094995775326360
# The new value in the search is 66266211231824447117620880943202
# Iteration number: 21
# The derivative is 132532422463648894235241761886402
# The change in value is 2650648449272977884704835237728040
# The new value in the search is -2584382238041153437587214356784838
# Iteration number: 22
# The derivative is -5168764476082306875174428713569678
# The change in value is -103375289521646137503488574271393560
# The new value in the search is 100790907283604984065901359914608722
# Iteration number: 23
# The derivative is 201581814567209968131802719829217442
# The change in value is 4031636291344199362636054396584348840
# The new value in the search is -3930845384060594378570153036669740118
# Iteration number: 24
# The derivative is -7861690768121188757140306073339480238
# The change in value is -157233815362423775142806121466789604760
# The new value in the search is 153302969978363180764235968430119864642
# Iteration number: 25
# The derivative is 306605939956726361528471936860239729282
# The change in value is 6132118799134527230569438737204794585640
# The new value in the search is -5978815829156164049805202768774674720998
# Iteration number: 26
# The derivative is -11957631658312328099610405537549349441998
# The change in value is -239152633166246561992208110750986988839960
# The new value in the search is 233173817337090397942402907982212314118962
# Iteration number: 27
# The derivative is 466347634674180795884805815964424628237922
# The change in value is 9326952693483615917696116319288492564758440
# The new value in the search is -9093778876146525519753713411306280250639478
# Iteration number: 28
# The derivative is -18187557752293051039507426822612560501278958
# The change in value is -363751155045861020790148536452251210025579160
# The new value in the search is 354657376169714495270394823040944929774939682
# Iteration number: 29
# The derivative is 709314752339428990540789646081889859549879362
# The change in value is 14186295046788579810815792921637797190997587240
# The new value in the search is -13831637670618865315545398098596852261222647558
# Iteration number: 30
# The derivative is -27663275341237730631090796197193704522445295118
# The change in value is -553265506824754612621815923943874090448905902360
# The new value in the search is 539433869154135747306270525845277238187683254802
# Iteration number: 31
# The derivative is 1078867738308271494612541051690554476375366509602
# The change in value is 21577354766165429892250821033811089527507330192040
# The new value in the search is -21037920897011294144944550507965812289319646937238
# Iteration number: 32
# The derivative is -42075841794022588289889101015931624578639293874478
# The change in value is -841516835880451765797782020318632491572785877489560
# The new value in the search is 820478914983440471652837469810666679283466230552322
# Iteration number: 33
# The derivative is 1640957829966880943305674939621333358566932461104642
# The change in value is 32819156599337618866113498792426667171338649222092840
# The new value in the search is -31998677684354178394460661322616000492055182991540518
# Iteration number: 34
# The derivative is -63997355368708356788921322645232000984110365983081038
# The change in value is -1279947107374167135778426452904640019682207319661620760
# The new value in the search is 1247948429689812957383965791582024019190152136670080242
# Iteration number: 35
# The derivative is 2495896859379625914767931583164048038380304273340160482
# The change in value is 49917937187592518295358631663280960767606085466803209640
# The new value in the search is -48669988757902705337974665871698936748415933330133129398
# Iteration number: 36
# The derivative is -97339977515805410675949331743397873496831866660266258798
# The change in value is -1946799550316108213518986634867957469936637333205325175960
# The new value in the search is 1898129561558205508181011968996258533188221399875192046562
# Iteration number: 37
# The derivative is 3796259123116411016362023937992517066376442799750384093122
# The change in value is 75925182462328220327240478759850341327528855995007681862440
# The new value in the search is -74027052900770014819059466790854082794340634595132489815878
# Iteration number: 38
# The derivative is -148054105801540029638118933581708165588681269190264979631758
# The change in value is -2961082116030800592762378671634163311773625383805299592635160
# The new value in the search is 2887055063130030577943319204843309228979284749210167102819282
# Iteration number: 39
# The derivative is 5774110126260061155886638409686618457958569498420334205638562
# The change in value is 115482202525201223117732768193732369159171389968406684112771240
# The new value in the search is -112595147462071192539789448988889059930192105219196517009951958
# Iteration number: 40
# The derivative is -225190294924142385079578897977778119860384210438393034019903918
# The change in value is -4503805898482847701591577959555562397207684208767860680398078360
# The new value in the search is 4391210751020776509051788510566673337277492103548664163388126402
# Iteration number: 41
# The derivative is 8782421502041553018103577021133346674554984207097328326776252802
# The change in value is 175648430040831060362071540422666933491099684141946566535525056040
# The new value in the search is -171257219289810283853019751912100260153822192038397902372136929638
# Iteration number: 42
# The derivative is -342514438579620567706039503824200520307644384076795804744273859278
# The change in value is -6850288771592411354120790076484010406152887681535916094885477185560
# The new value in the search is 6679031552302601070267770324571910145999065489497518192513340255922
# Iteration number: 43
# The derivative is 13358063104605202140535540649143820291998130978995036385026680511842
# The change in value is 267161262092104042810710812982876405839962619579900727700533610236840
# The new value in the search is -260482230539801441740443042658304495693963554090403209508020269980918
# Iteration number: 44
# The derivative is -520964461079602883480886085316608991387927108180806419016040539961838
# The change in value is -10419289221592057669617721706332179827758542163616128380320810799236760
# The new value in the search is 10158806991052256227877278663673875332064578609525725170812790529255842
# Iteration number: 45
# The derivative is 20317613982104512455754557327347750664129157219051450341625581058511682
# The change in value is 406352279642090249115091146546955013282583144381029006832511621170233640
# The new value in the search is -396193472651037992887213867883281137950518565771503281661698830640977798
# Iteration number: 46
# The derivative is -792386945302075985774427735766562275901037131543006563323397661281955598
# The change in value is -15847738906041519715488554715331245518020742630860131266467953225639111960
# The new value in the search is 15451545433390481722601340847447964380070224065088627984806254394998134162
# Iteration number: 47
# The derivative is 30903090866780963445202681694895928760140448130177255969612508789996268322
# The change in value is 618061817335619268904053633897918575202808962603545119392250175799925366440
# The new value in the search is -602610271902228787181452293050470610822738738538456491407443921404927232278
# Iteration number: 48
# The derivative is -1205220543804457574362904586100941221645477477076912982814887842809854464558
# The change in value is -24104410876089151487258091722018824432909549541538259656297756856197089291160
# The new value in the search is 23501800604186922700076639428968353822086810802999803164890312934792162058882
# Iteration number: 49
# The derivative is 47003601208373845400153278857936707644173621605999606329780625869584324117762
# The change in value is 940072024167476908003065577158734152883472432119992126595612517391686482355240
# The new value in the search is -916570223563289985302988937729765799061385621316992323430722204456894320296358
# Iteration number: 50
# The derivative is -1833140447126579970605977875459531598122771242633984646861444408913788640592718
# The change in value is -36662808942531599412119557509190631962455424852679692937228888178275772811854360
# The new value in the search is 35746238718968309426816568571460866163394039231362700613798165973818878491558002
# answer is 35746238718968309426816568571460866163394039231362700613798165973818878491558002
